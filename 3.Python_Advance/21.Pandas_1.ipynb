# %%
import numpy as np
import pandas as pd

# %%
dict_1={
    "Name"  :["Shreya" , "Rohan" , "Skiff" , "Shubh"],
    "Marks" :[92,34,24,17],
    "City"  :["Rampur" , "Kolkata" , "Bareilly" , "Antarctica"]
}

# %%
#Convert the above to an excel scheet like document/format
#INDEX=ROW

df=pd.DataFrame(dict_1)
df
# Out:
#      Name  Marks        City
# 0  Shreya     92      Rampur
# 1   Rohan     34     Kolkata
# 2   Skiff     24    Bareilly
# 3   Shubh     17  Antarctica

# %%
#Convert the data frame to csv file, check in the folder
df.to_csv("Friends.csv")

# %%
#Convert the data frame to csv file without indexes
df.to_csv("Friends_noindex.csv",index=False)

# %%
#o/p first two rows
df.head(2)
# Out:
#      Name  Marks     City
# 0  Shreya     92   Rampur
# 1   Rohan     34  Kolkata

# %%
#By default it gives first 5 rows
df.head()
# Out:
#      Name  Marks        City
# 0  Shreya     92      Rampur
# 1   Rohan     34     Kolkata
# 2   Skiff     24    Bareilly
# 3   Shubh     17  Antarctica

# %%
#last two rows
df.tail(2)
# Out:
#     Name  Marks        City
# 2  Skiff     24    Bareilly
# 3  Shubh     17  Antarctica

# %%
df.describe()
# Out:
#           Marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
#Create a csv file Shreya.csv

# %%
#Store the content of the above file
shreya=pd.read_csv("shreya.csv")
shreya
# Out:
#    Unnamed: 0  Train No.  Speed        City
# 0           0      12322     50      Rampur
# 1           1      12534    123     Kolkata
# 2           2     125654     67    Bareilly
# 3           3     564523     87  Antarctica

# %%
#Change the speed from 34 to 50
shreya['Speed'][0]=50
shreya
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12996\3446480819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shreya['Speed'][0]=50
#    Unnamed: 0  Train No.  Speed        City
# 0           0      12322     50      Rampur
# 1           1      12534    123     Kolkata
# 2           2     125654     67    Bareilly
# 3           3     564523     87  Antarctica

# %%
shreya.to_csv('shreya.csv')

# %%
#Change the index
shreya.index=["first","second","third","fourth"]
shreya
# Out:
#         Unnamed: 0  Train No.  Speed        City
# first            0      12322     50      Rampur
# second           1      12534    123     Kolkata
# third            2     125654     67    Bareilly
# fourth           3     564523     87  Antarctica

# %% [markdown]
# # What is Panda?

# %% [raw]
# Open source data analysis libraray written in python.
#
# WHY ARE WE USING PANDA, WHY NOT EXCEL SHEET DIRECTLY?
# To leverage the power and efficiency of this library.To make things easy.
#
# PANDAS has TWO TYPES OF DATASTRUCTURE
# 1.Series :Data are store in 1D format(either row/column) having only one type of data
# 2.Dataframe Tabular spreadsheet having anytype of data.

# %%
#Give index to the random numbers between 0 to 1 of size 34

ser=pd.Series(np.random.rand(34))
ser
# Out:
# 0     0.772124
# 1     0.759366
# 2     0.329464
# 3     0.724546
# 4     0.649281
# 5     0.370888
# 6     0.879403
# 7     0.573042
# 8     0.411282
# 9     0.692857
# 10    0.966943
# 11    0.952733
# 12    0.707531
# 13    0.018191
# 14    0.706343
# 15    0.815819
# 16    0.947656
# 17    0.404707
# 18    0.818698
# 19    0.974447
# 20    0.009987
# 21    0.777287
# 22    0.457458
# 23    0.843249
# 24    0.879494
# 25    0.279900
# 26    0.769820
# 27    0.889799
# 28    0.684816
# 29    0.298317
# 30    0.520770
# 31    0.645581
# 32    0.122215
# 33    0.644519
# dtype: float64

# %%
#Give index to the rows, having 100 rows and 5 columns
newdf=pd.DataFrame(np.random.rand(100,5),index=np.arange(100))
newdf
# Out:
#            0         1         2         3         4
# 0   0.018126  0.525242  0.382298  0.943510  0.178250
# 1   0.901716  0.241849  0.414825  0.350392  0.052427
# 2   0.706220  0.456507  0.302742  0.937132  0.988342
# 3   0.508859  0.061053  0.991932  0.746848  0.505672
# 4   0.822330  0.570105  0.029422  0.887146  0.754796
# ..       ...       ...       ...       ...       ...
# 95  0.237591  0.000531  0.367121  0.995348  0.713532
# 96  0.148549  0.887182  0.245452  0.834597  0.170077
# 97  0.904056  0.857825  0.756123  0.852899  0.690477
# 98  0.674224  0.714325  0.210545  0.620667  0.735378
# 99  0.362305  0.999376  0.534969  0.950104  0.939024
#
# [100 rows x 5 columns]

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
#Convert to numpy array

a=newdf.to_numpy()
a
# Out:
# array([[1.81255701e-02, 5.25242055e-01, 3.82297706e-01, 9.43510220e-01,
#         1.78249606e-01],
#        [9.01716250e-01, 2.41849404e-01, 4.14825016e-01, 3.50391866e-01,
#         5.24273907e-02],
#        [7.06219774e-01, 4.56507055e-01, 3.02741941e-01, 9.37132353e-01,
#         9.88342313e-01],
#        [5.08858875e-01, 6.10534942e-02, 9.91931892e-01, 7.46847610e-01,
#         5.05672078e-01],
#        [8.22329860e-01, 5.70104734e-01, 2.94217678e-02, 8.87145887e-01,
#         7.54795796e-01],
#        [6.51080308e-01, 5.41890557e-01, 5.15428415e-01, 5.71745827e-01,
#         8.59861040e-01],
#        [6.52553156e-01, 8.84085083e-01, 5.21442705e-01, 6.78524298e-01,
#         2.66372790e-01],
#        [8.31770919e-01, 4.33375439e-03, 3.38635723e-02, 4.36595270e-01,
#         6.82606399e-01],
#        [1.38476991e-01, 7.00826133e-01, 9.36557890e-01, 1.82157951e-01,
#         4.25886653e-01],
#        [3.77489788e-01, 6.92608957e-01, 4.27166576e-01, 4.73979536e-01,
# ...

# %% [markdown]
# # VIEW

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0.018126  0.525242  0.382298  0.943510  0.178250
# 1   0.901716  0.241849  0.414825  0.350392  0.052427
# 2   0.706220  0.456507  0.302742  0.937132  0.988342
# 3   0.508859  0.061053  0.991932  0.746848  0.505672
# 4   0.822330  0.570105  0.029422  0.887146  0.754796
# ..       ...       ...       ...       ...       ...
# 95  0.237591  0.000531  0.367121  0.995348  0.713532
# 96  0.148549  0.887182  0.245452  0.834597  0.170077
# 97  0.904056  0.857825  0.756123  0.852899  0.690477
# 98  0.674224  0.714325  0.210545  0.620667  0.735378
# 99  0.362305  0.999376  0.534969  0.950104  0.939024
#
# [100 rows x 5 columns]

# %%
newdf2=newdf
newdf2
# Out:
#            0         1         2         3         4
# 0   0.018126  0.525242  0.382298  0.943510  0.178250
# 1   0.901716  0.241849  0.414825  0.350392  0.052427
# 2   0.706220  0.456507  0.302742  0.937132  0.988342
# 3   0.508859  0.061053  0.991932  0.746848  0.505672
# 4   0.822330  0.570105  0.029422  0.887146  0.754796
# ..       ...       ...       ...       ...       ...
# 95  0.237591  0.000531  0.367121  0.995348  0.713532
# 96  0.148549  0.887182  0.245452  0.834597  0.170077
# 97  0.904056  0.857825  0.756123  0.852899  0.690477
# 98  0.674224  0.714325  0.210545  0.620667  0.735378
# 99  0.362305  0.999376  0.534969  0.950104  0.939024
#
# [100 rows x 5 columns]

# %%
newdf2[0][0]=9783
newdf2
# Out:
#               0         1         2         3         4
# 0   9783.000000  0.525242  0.382298  0.943510  0.178250
# 1      0.901716  0.241849  0.414825  0.350392  0.052427
# 2      0.706220  0.456507  0.302742  0.937132  0.988342
# 3      0.508859  0.061053  0.991932  0.746848  0.505672
# 4      0.822330  0.570105  0.029422  0.887146  0.754796
# ..          ...       ...       ...       ...       ...
# 95     0.237591  0.000531  0.367121  0.995348  0.713532
# 96     0.148549  0.887182  0.245452  0.834597  0.170077
# 97     0.904056  0.857825  0.756123  0.852899  0.690477
# 98     0.674224  0.714325  0.210545  0.620667  0.735378
# 99     0.362305  0.999376  0.534969  0.950104  0.939024
#
# [100 rows x 5 columns]

# %%
#Value for newdf also changed,but WHY?
#Because we have created VIEWs, which means that bothh the object will point to same address
newdf
# Out:
#               0         1         2         3         4
# 0   9783.000000  0.987678  0.047303  0.673510  0.119978
# 1      0.154600  0.812286  0.104046  0.008920  0.254328
# 2      0.865876  0.301517  0.818555  0.056457  0.797726
# 3      0.603386  0.750441  0.203893  0.482234  0.241482
# 4      0.504948  0.634767  0.651340  0.138575  0.190143
# ..          ...       ...       ...       ...       ...
# 95     0.170530  0.702547  0.353023  0.832280  0.754040
# 96     0.783167  0.470880  0.531648  0.162674  0.917081
# 97     0.370964  0.704162  0.688221  0.875703  0.937799
# 98     0.044924  0.085572  0.826255  0.538723  0.243298
# 99     0.930985  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 5 columns]

# %%
#To avoid the above situation we do the following

newdf2=newdf.copy()
newdf2[0][0]=1000

# %%
newdf2
# Out:
#               0         1         2         3         4
# 0   1000.000000  0.987678  0.047303  0.673510  0.119978
# 1      0.154600  0.812286  0.104046  0.008920  0.254328
# 2      0.865876  0.301517  0.818555  0.056457  0.797726
# 3      0.603386  0.750441  0.203893  0.482234  0.241482
# 4      0.504948  0.634767  0.651340  0.138575  0.190143
# ..          ...       ...       ...       ...       ...
# 95     0.170530  0.702547  0.353023  0.832280  0.754040
# 96     0.783167  0.470880  0.531648  0.162674  0.917081
# 97     0.370964  0.704162  0.688221  0.875703  0.937799
# 98     0.044924  0.085572  0.826255  0.538723  0.243298
# 99     0.930985  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 5 columns]

# %%
newdf
# Out:
#               0         1         2         3         4
# 0   9783.000000  0.987678  0.047303  0.673510  0.119978
# 1      0.154600  0.812286  0.104046  0.008920  0.254328
# 2      0.865876  0.301517  0.818555  0.056457  0.797726
# 3      0.603386  0.750441  0.203893  0.482234  0.241482
# 4      0.504948  0.634767  0.651340  0.138575  0.190143
# ..          ...       ...       ...       ...       ...
# 95     0.170530  0.702547  0.353023  0.832280  0.754040
# 96     0.783167  0.470880  0.531648  0.162674  0.917081
# 97     0.370964  0.704162  0.688221  0.875703  0.937799
# 98     0.044924  0.085572  0.826255  0.538723  0.243298
# 99     0.930985  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 5 columns]

# %%
#Changing value at a required position
#Below is the correct way of doing it

newdf.loc[0,0]=0.805425
newdf
# Out:
#            0         1         2         3         4
# 0   0.805425  0.987678  0.047303  0.673510  0.119978
# 1   0.154600  0.812286  0.104046  0.008920  0.254328
# 2   0.865876  0.301517  0.818555  0.056457  0.797726
# 3   0.603386  0.750441  0.203893  0.482234  0.241482
# 4   0.504948  0.634767  0.651340  0.138575  0.190143
# ..       ...       ...       ...       ...       ...
# 95  0.170530  0.702547  0.353023  0.832280  0.754040
# 96  0.783167  0.470880  0.531648  0.162674  0.917081
# 97  0.370964  0.704162  0.688221  0.875703  0.937799
# 98  0.044924  0.085572  0.826255  0.538723  0.243298
# 99  0.930985  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.805425  0.987678  0.047303  0.673510  0.119978
# 1  0.154600  0.812286  0.104046  0.008920  0.254328
# 2  0.865876  0.301517  0.818555  0.056457  0.797726
# 3  0.603386  0.750441  0.203893  0.482234  0.241482
# 4  0.504948  0.634767  0.651340  0.138575  0.190143

# %%
newdf.tail()
# Out:
#            0         1         2         3         4
# 95  0.170530  0.702547  0.353023  0.832280  0.754040
# 96  0.783167  0.470880  0.531648  0.162674  0.917081
# 97  0.370964  0.704162  0.688221  0.875703  0.937799
# 98  0.044924  0.085572  0.826255  0.538723  0.243298
# 99  0.930985  0.362843  0.851033  0.106910  0.449684

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.468146    0.508896    0.504148    0.507390    0.553028
# std      0.283923    0.285101    0.294382    0.273402    0.302798
# min      0.002701    0.009622    0.010294    0.008920    0.000697
# 25%      0.247731    0.262860    0.260811    0.292992    0.302651
# 50%      0.478938    0.527381    0.528094    0.591944    0.579384
# 75%      0.670951    0.752776    0.736862    0.714359    0.834722
# max      0.976753    0.991963    0.987900    0.992621    0.993955

# %%
#Change the column name

newdf.columns=list("ABCDE")
newdf
# Out:
#            A         B         C         D         E
# 0   0.805425  0.987678  0.047303  0.673510  0.119978
# 1   0.154600  0.812286  0.104046  0.008920  0.254328
# 2   0.865876  0.301517  0.818555  0.056457  0.797726
# 3   0.603386  0.750441  0.203893  0.482234  0.241482
# 4   0.504948  0.634767  0.651340  0.138575  0.190143
# ..       ...       ...       ...       ...       ...
# 95  0.170530  0.702547  0.353023  0.832280  0.754040
# 96  0.783167  0.470880  0.531648  0.162674  0.917081
# 97  0.370964  0.704162  0.688221  0.875703  0.937799
# 98  0.044924  0.085572  0.826255  0.538723  0.243298
# 99  0.930985  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 5 columns]

# %% [markdown]
# # To remove column or row

# %%
newdf.drop("A",axis=1)
# Out:
#            B         C         D         E
# 0   0.987678  0.047303  0.673510  0.119978
# 1   0.812286  0.104046  0.008920  0.254328
# 2   0.301517  0.818555  0.056457  0.797726
# 3   0.750441  0.203893  0.482234  0.241482
# 4   0.634767  0.651340  0.138575  0.190143
# ..       ...       ...       ...       ...
# 95  0.702547  0.353023  0.832280  0.754040
# 96  0.470880  0.531648  0.162674  0.917081
# 97  0.704162  0.688221  0.875703  0.937799
# 98  0.085572  0.826255  0.538723  0.243298
# 99  0.362843  0.851033  0.106910  0.449684
#
# [100 rows x 4 columns]

# %%
newdf.drop(0,axis=0)
# Out:
#            A         B         C         D         E
# 1   0.154600  0.812286  0.104046  0.008920  0.254328
# 2   0.865876  0.301517  0.818555  0.056457  0.797726
# 3   0.603386  0.750441  0.203893  0.482234  0.241482
# 4   0.504948  0.634767  0.651340  0.138575  0.190143
# 5   0.459308  0.200726  0.024094  0.366685  0.740436
# ..       ...       ...       ...       ...       ...
# 95  0.170530  0.702547  0.353023  0.832280  0.754040
# 96  0.783167  0.470880  0.531648  0.162674  0.917081
# 97  0.370964  0.704162  0.688221  0.875703  0.937799
# 98  0.044924  0.085572  0.826255  0.538723  0.243298
# 99  0.930985  0.362843  0.851033  0.106910  0.449684
#
# [99 rows x 5 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    float64
#  2   C       100 non-null    float64
#  3   D       100 non-null    float64
#  4   E       100 non-null    float64
# dtypes: float64(5)
# memory usage: 8.8 KB

# %% [markdown]
# # METHODS

# %% [raw]
# newdf.describe()
# newdf.mean()
# newdf.max()
# newdf.min()
# newdf.count()
# newdf.median()
